# %%
# %load_ext autoreload
# %autoreload 2
import extract_in_cosmodc2 as extract_cosmodc2
import lens_data as lens
import matplotlib.pyplot as plt
import GCRCatalogs
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Lens catalog

# %%
lens_catalog = lens.lens_catalog
index = 10

# %% [markdown]
# ## Cosmodc2 with qserv

# %%
#z, ra, dec = lens_catalog['redshift'][index], lens_catalog['ra'][index], lens_catalog['dec'][index]
z, ra, dec = .9, 65, -40

# %%
bckgd_galaxy_catalog = extract_cosmodc2.extract(lens_redshift = z, lens_ra = ra, lens_dec = dec)

# %%
bckgd_galaxy_catalog
# Out:
# GalaxyCluster GalaxyCluster: (ra=65.0, dec=-40.0) at z=0.9
# > with columns: ra, dec, z, galaxy_id, mag_i, mag_r, mag_y, shear1, shear2, kappa, e1_true, e2_true, g1, g2, e1, e2, chi1, chi2, w_ls_true
# > 5553 source galaxies

# %%
gc_flex = GCRCatalogs.load_catalog("cosmoDC2_v1.1.4_small_with_photozs_flexzboost_v1")
gc_bpz  = GCRCatalogs.load_catalog("cosmoDC2_v1.1.4_small_with_photozs_v1")
z_bins  = gc_flex.photoz_pdf_bin_centers

# %%
bckgd_galaxy_catalog = extract_cosmodc2.extract(lens_redshift = z, lens_ra = ra, lens_dec = dec, 
                                     photoz=True, photoz_label='flex', GCRcatalog=gc_flex)

# %% [markdown]
# ## DC2 with GCR catalog

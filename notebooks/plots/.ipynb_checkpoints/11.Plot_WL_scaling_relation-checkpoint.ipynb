# %%
# %load_ext autoreload

# %autoreload 2
import matplotlib.pyplot as plt
import pickle
from astropy.coordinates import SkyCoord, match_coordinates_3d, match_coordinates_sky
import sys
import emcee
import numpy as np
from astropy.cosmology import FlatLambdaCDM
import astropy.units as u
from astropy.table import Table, QTable, hstack, vstack
from astropy import units as u
import corner
from astropy.coordinates import SkyCoord, match_coordinates_3d
cosmo_astropy = FlatLambdaCDM(H0=71.0, Om0=0.265, Ob0 = 0.0448)
import iminuit
from iminuit import Minuit
sys.path.append('/pbs/throng/lsst/users/cpayerne/CLMassDC2/modules/')
import analysis_Mass_Richness_relation as analysis
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import glob
file = glob.glob('/pbs/throng/lsst/users/cpayerne/CLMassDC2/notebooks/plots/WL_mean_masses/*')

# %%
name = [f.split('_mean_masses/')[1].split('.pkl')[0] for f in file]

# %%
name
# Out:
# ['cM_nfw_Prada12',
#  'PZ_nfw_Diemer15_BPZ',
#  'PZ_nfw_Diemer15_flex',
#  '2h_nfw_two_halo_term_freec',
#  '2h_nfw_two_halo_term_Diemer15',
#  'cM_nfw_Duffy08',
#  'cM_nfw_Diemer15',
#  'halomodel_hernquist_freec',
#  'halomodel_nfw_freec',
#  'cM_nfw_Bhattacharya13',
#  'halomodel_einasto_freec']

# %%
name_plot = ['Prada12', ]

# %%
masses = {n:None for n in name}

# %%
masses['cM_nfw_Prada12']

# %%
for i,f in enumerate(file):
    masses[name[i]] = np.load(f, allow_pickle=True)

# %%
masses[name[0]]
# Out:
# {'masses': <Table length=28>
#       mask      ...
#     bool[15]    ...
#  -------------- ...
#  False .. False ...
#  False .. False ...
#  False .. False ...
#  False .. False ...
#  False .. False ...
#  False .. False ...
#  False .. False ...
#  False .. False ...
#  False .. False ...
#  False .. False ...
#             ... ...
#  False .. False ...
#  False .. False ...
#  False .. False ...
#  False .. False ...
#  False .. False ...
#  False .. False ...
#  False .. False ...
#  False .. False ...
#  False .. False ...
#  False .. False ...,
#  'name_analysis': 'NFW (1h) - Prada12'}

# %%
for k, m in enumerate(analysis.Obs_bin):
    name_analysis = ['PZ', '2h', 'cM', 'halomodel']
    color = ['C0', 'C1', 'C2', 'C3']
    marker = ['o','x','d','s']
    for i, analysis_ in enumerate(name_analysis):
        for j, n in enumerate(name):
            if np.isin(analysis_, n.split('_')[0]):
                mask = (masses[n]['masses']['obs_mean'] > m[0])*(masses[n]['masses']['obs_mean'] < m[1])
                mask = mask*(masses[n]['masses']['z_mean'] > 0.2)*(masses[n]['masses']['z_mean'] < 0.3)
                plt.errorbar(masses[n]['masses']['log10M200c_WL'][mask],masses[n]['name_analysis'], xerr = masses[n]['masses']['err_log10M200c_WL'][mask], color = color[i], marker = marker[k], capsize=3,)
plt.xticks(rotation = 0)
plt.xlabel(r'$\log_{10}M_{\rm 200c}\ [M_\odot]$', fontsize=20)
#plt.ylim(14, 14.8)
# Out:
# Text(0.5, 0, '$\\log_{10}M_{\\rm 200c}\\ [M_\\odot]$')

# %%
f =mass_file_nfw_freec
#f = mass_file_einasto_freec
#f = mass_file_hernquist_freec
for k, z_bin in enumerate(Z_bin):
        f = Table(f)
        plt.plot([],[], '-',label = f'{z_bin[0]:.2f}'+ r'$< z < $'+ f'{z_bin[1]:.2f}',)
        mask = (f['z_mean'] > z_bin[0])*(f['z_mean'] < z_bin[1])
        f_cut = f[mask]
        richness = f_cut['obs_mean']
        richness_err = f_cut['obs_rms']
        logm200w = f_cut['log10M200c_WL']
        logm200w_err = f_cut['err_log10M200c_WL']
        
        #logm200w = f_cut['logm200_w']
        #logm200w_err = f_cut['logm200_w_err']
        plt.errorbar(richness,logm200w,logm200w_err, richness_err)

plt.xscale('log')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 f =mass_file_nfw_freec
#       2 #f = mass_file_einasto_freec
#       3 #f = mass_file_hernquist_freec
#       4 for k, z_bin in enumerate(Z_bin):
#
# NameError: name 'mass_file_nfw_freec' is not defined
